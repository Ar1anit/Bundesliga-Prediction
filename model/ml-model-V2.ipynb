# %%
import pandas as pd

# %%
matches = pd.read_csv('../datasets/merge.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/arian/VS-Projects/Bundesliga Prediction/model/ml-model-V2.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/arian/VS-Projects/Bundesliga%20Prediction/model/ml-model-V2.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> matches = pd.read_csv('../datasets/merge.csv')
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/io/parsers/readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:814, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:875, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~/anaconda3/envs/bulipred/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:2029, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 105 fields in line 919, saw 106

# %%
matches.head()
# Out:
#   Div        Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  \
# 0  D1  16/08/2019  19:30  Bayern Munich              Hertha     2     2   D
# 1  D1  17/08/2019  14:30       Dortmund            Augsburg     5     1   H
# 2  D1  17/08/2019  14:30       Freiburg               Mainz     3     0   H
# 3  D1  17/08/2019  14:30     Leverkusen           Paderborn     3     2   H
# 4  D1  17/08/2019  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A
#
#    HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1     2  ...     3.40 -2.25      2.03      1.90   1.99   1.93     2.04
# 1     1     1  ...     3.31 -2.25      1.92      2.01   1.92   2.00     1.98
# 2     0     0  ...     1.89  0.00      1.92      2.01   1.94   1.97     1.97
# 3     2     2  ...     3.58 -2.00      2.07      1.86   2.05   1.86     2.15
# 4     0     1  ...     2.26 -0.75      1.92      2.01   1.92   2.00     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.93     1.98     1.91
# 1     2.04     1.91     1.97
# 2     2.06     1.90     1.99
# 3     1.91     2.03     1.85
# 4     2.11     1.89     2.00
#
# [5 rows x 105 columns]

# %%
matches.shape
# Out:
# (918, 105)

# %%
matches["HomeTeam"].value_counts()
# Out:
# HomeTeam
# Bayern Munich         51
# Union Berlin          51
# Hertha                51
# RB Leipzig            51
# Mainz                 51
# Hoffenheim            51
# Dortmund              51
# Augsburg              51
# FC Koln               51
# Ein Frankfurt         51
# M'gladbach            51
# Wolfsburg             51
# Leverkusen            51
# Freiburg              51
# Bielefeld             34
# Werder Bremen         34
# Schalke 04            34
# Stuttgart             34
# Bochum                17
# Fortuna Dusseldorf    17
# Paderborn             17
# Greuther Furth        17
# Name: count, dtype: int64

# %%
matches[matches["HomeTeam"] == "Bayern Munich"]
# Out:
#     Div        Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  \
# 0    D1  16/08/2019  19:30  Bayern Munich              Hertha     2     2   D
# 739  D1  11/12/2021  14:30  Bayern Munich               Mainz     2     1   H
# 756  D1  17/12/2021  19:30  Bayern Munich           Wolfsburg     4     0   H
# 765  D1  07/01/2022  19:30  Bayern Munich          M'gladbach     1     2   A
# 798  D1  05/02/2022  17:30  Bayern Munich          RB Leipzig     3     2   H
# 816  D1  20/02/2022  14:30  Bayern Munich      Greuther Furth     4     1   H
# 829  D1  05/03/2022  14:30  Bayern Munich          Leverkusen     1     1   D
# 850  D1  19/03/2022  17:30  Bayern Munich        Union Berlin     4     0   H
# 865  D1  09/04/2022  14:30  Bayern Munich            Augsburg     1     0   H
# 888  D1  23/04/2022  17:30  Bayern Munich            Dortmund     3     1   H
# 907  D1  08/05/2022  16:30  Bayern Munich           Stuttgart     2     2   D
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0       1     2  ...     3.40 -2.25      2.03      1.90   1.99   1.93
# 19      2     1  ...     4.32 -2.75      2.05      1.88   2.03   1.88
# 37      1     0  ...     4.07 -2.50      1.86      2.07   1.86   2.06
# 55      0     0  ...     4.91 -2.75      1.94      1.99   1.92   2.00
# 73      1     0  ...     4.49 -2.75      1.96      1.97   1.95   1.96
# 95      1     0  ...     2.99 -1.00      1.92      2.01   1.93   1.99
# 113     1     2  ...     3.93 -2.00      2.02      1.91   2.01   1.90
# 127     2     1  ...     4.77 -2.75      1.93      2.00   1.93   1.98
# 145     0     0  ...     3.39 -2.00      1.93      2.00   1.91   2.00
# 168     2     0  ...     3.68 -2.25      2.02      1.91   2.04   1.88
# 187     0     0  ...     3.69 -1.25      1.89      2.04   1.88   2.03
# 197     1     1  ...     6.23 -3.25      1.92      2.01   1.92   1.99
# 221     0     0  ...     4.95 -2.75      1.94      1.99   1.94   1.97
# 238     2     0  ...     4.06 -2.50      2.10      1.80   2.09   1.81
# 256     3     0  ...     4.43 -2.75      1.85      2.08   1.85   2.05
# 276     1     1  ...     2.83 -1.25      1.99      1.94   1.98   1.93
# 288     3     1  ...     3.35 -1.75      2.07      1.86   2.05   1.85
# 306     3     0  ...     4.34 -2.50      1.89      2.04   1.87   2.02
# 332     1     0  ...     4.20 -2.25      1.99      1.94   1.98   1.92
# 343     2     0  ...     5.19 -2.25      1.87      2.03   1.88   2.03
# 369     0     1  ...     4.01 -2.50      2.00      1.80   2.03   1.88
# 392     2     2  ...     2.99 -1.00      2.10      1.83   2.10   1.84
# 410     1     1  ...     3.51 -1.50      1.89      2.04   1.89   2.03
# 431     0     2  ...     5.01 -2.75      1.89      2.04   1.87   2.02
# 448     1     0  ...     3.58 -2.00      2.04      1.89   2.02   1.89
# 469     2     1  ...     4.47 -2.00      1.92      2.01   1.89   2.02
# 493     0     2  ...     2.97 -2.25      2.07      1.86   2.09   1.81
# 504     2     0  ...     3.15 -2.00      2.02      1.91   2.02   1.89
# 518     2     2  ...     3.31 -1.00      1.86      2.07   1.86   2.07
# 532     4     0  ...     3.97 -1.75      1.90      2.03   1.88   2.03
# 550     0     0  ...     2.07 -0.50      1.89      2.01   1.89   2.03
# 567     2     0  ...     2.90 -1.00      1.87      2.06   1.89   2.03
# 589     4     0  ...     3.94 -1.50      2.02      1.77   2.11   1.82
# 850     1.82     2.24     1.77     2.10
# 865     2.05     2.07     1.96     1.90
# 888     2.12     1.99     1.93     1.93
# 907     1.98     2.18     1.86     2.00
#
# [51 rows x 105 columns]

# %%
matches.dtypes
# Out:
# Div          object
# Date         object
# Time         object
# HomeTeam     object
# AwayTeam     object
#              ...
# PCAHA       float64
# MaxCAHH     float64
# MaxCAHA     float64
# AvgCAHH     float64
# AvgCAHA     float64
# Length: 105, dtype: object

# %%
matches.drop(["Div"], axis="columns", inplace=True)

# %%
matches.head()
# Out:
#          Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  16/08/2019  19:30  Bayern Munich              Hertha     2     2   D     1
# 1  17/08/2019  14:30       Dortmund            Augsburg     5     1   H     1
# 2  17/08/2019  14:30       Freiburg               Mainz     3     0   H     0
# 3  17/08/2019  14:30     Leverkusen           Paderborn     3     2   H     2
# 4  17/08/2019  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     2   A  ...      3.40 -2.25      2.03      1.90   1.99   1.93     2.04
# 1     1   D  ...      3.31 -2.25      1.92      2.01   1.92   2.00     1.98
# 2     0   D  ...      1.89  0.00      1.92      2.01   1.94   1.97     1.97
# 3     2   D  ...      3.58 -2.00      2.07      1.86   2.05   1.86     2.15
# 4     1   A  ...      2.26 -0.75      1.92      2.01   1.92   2.00     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.93     1.98     1.91
# 1     2.04     1.91     1.97
# 2     2.06     1.90     1.99
# 3     1.91     2.03     1.85
# 4     2.11     1.89     2.00
#
# [5 rows x 104 columns]

# %%
matches["Date"] = pd.to_datetime(matches["Date"])
# Out:
# /var/folders/lw/pygk9wrs0711t4dprf56xt_m0000gn/T/ipykernel_62459/254043194.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   matches["Date"] = pd.to_datetime(matches["Date"])

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     2   A  ...      3.40 -2.25      2.03      1.90   1.99   1.93     2.04
# 1     1   D  ...      3.31 -2.25      1.92      2.01   1.92   2.00     1.98
# 2     0   D  ...      1.89  0.00      1.92      2.01   1.94   1.97     1.97
# 3     2   D  ...      3.58 -2.00      2.07      1.86   2.05   1.86     2.15
# 4     1   A  ...      2.26 -0.75      1.92      2.01   1.92   2.00     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.93     1.98     1.91
# 1     2.04     1.91     1.97
# 2     2.06     1.90     1.99
# 3     1.91     2.03     1.85
# 4     2.11     1.89     2.00
#
# [5 rows x 104 columns]

# %%
matches["FTR_codes"] = matches["FTR"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0     2   A  ... -2.25      2.03      1.90   1.99   1.93     2.04     1.93
# 1     1   D  ... -2.25      1.92      2.01   1.92   2.00     1.98     2.04
# 2     0   D  ...  0.00      1.92      2.01   1.94   1.97     1.97     2.06
# 3     2   D  ... -2.00      2.07      1.86   2.05   1.86     2.15     1.91
# 4     1   A  ... -0.75      1.92      2.01   1.92   2.00     1.95     2.11
#
#    AvgCAHH  AvgCAHA  FTR_codes
# 0     1.98     1.91          1
# 1     1.91     1.97          2
# 2     1.90     1.99          2
# 3     2.03     1.85          2
# 4     1.89     2.00          0
#
# [5 rows x 105 columns]

# %%
matches["HTR_codes"] = matches["HTR"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     2   A  ...      2.03      1.90   1.99   1.93     2.04     1.93     1.98
# 1     1   D  ...      1.92      2.01   1.92   2.00     1.98     2.04     1.91
# 2     0   D  ...      1.92      2.01   1.94   1.97     1.97     2.06     1.90
# 3     2   D  ...      2.07      1.86   2.05   1.86     2.15     1.91     2.03
# 4     1   A  ...      1.92      2.01   1.92   2.00     1.95     2.11     1.89
#
#    AvgCAHA  FTR_codes  HTR_codes
# 0     1.91          1          0
# 1     1.97          2          1
# 2     1.99          2          1
# 3     1.85          2          1
# 4     2.00          0          0
#
# [5 rows x 106 columns]

# %%
matches["opp_codes"] = matches["AwayTeam"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0     2   A  ...      1.90   1.99   1.93     2.04     1.93     1.98     1.91
# 1     1   D  ...      2.01   1.92   2.00     1.98     2.04     1.91     1.97
# 2     0   D  ...      2.01   1.94   1.97     1.97     2.06     1.90     1.99
# 3     2   D  ...      1.86   2.05   1.86     2.15     1.91     2.03     1.85
# 4     1   A  ...      2.01   1.92   2.00     1.95     2.11     1.89     2.00
#
#    FTR_codes  HTR_codes  opp_codes
# 0          1          0         10
# 1          2          1          0
# 2          2          1         14
# 3          2          1         15
# 4          0          0          7
#
# [5 rows x 107 columns]

# %%
matches["team_codes"] = matches["HomeTeam"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  FTR_codes  \
# 0     2   A  ...   1.99   1.93     2.04     1.93     1.98     1.91          1
# 1     1   D  ...   1.92   2.00     1.98     2.04     1.91     1.97          2
# 2     0   D  ...   1.94   1.97     1.97     2.06     1.90     1.99          2
# 3     2   D  ...   2.05   1.86     2.15     1.91     2.03     1.85          2
# 4     1   A  ...   1.92   2.00     1.95     2.11     1.89     2.00          0
#
#    HTR_codes  opp_codes  team_codes
# 0          0         10           1
# 1          1          0           4
# 2          1         14           8
# 3          1         15          12
# 4          0          7          20
#
# [5 rows x 108 columns]

# %%
matches["hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  FTR_codes  \
# 0     2   A  ...   1.93     2.04     1.93     1.98     1.91          1
# 1     1   D  ...   2.00     1.98     2.04     1.91     1.97          2
# 2     0   D  ...   1.97     1.97     2.06     1.90     1.99          2
# 3     2   D  ...   1.86     2.15     1.91     2.03     1.85          2
# 4     1   A  ...   2.00     1.95     2.11     1.89     2.00          0
#
#    HTR_codes  opp_codes  team_codes  hour
# 0          0         10           1    19
# 1          1          0           4    14
# 2          1         14           8    14
# 3          1         15          12    14
# 4          0          7          20    14
#
# [5 rows x 109 columns]

# %%
matches["day_code"] = matches["Date"].dt.day_of_week

# %%
matches.head()
# Out:
#         Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0 2019-08-16  19:30  Bayern Munich              Hertha     2     2   D     1
# 1 2019-08-17  14:30       Dortmund            Augsburg     5     1   H     1
# 2 2019-08-17  14:30       Freiburg               Mainz     3     0   H     0
# 3 2019-08-17  14:30     Leverkusen           Paderborn     3     2   H     2
# 4 2019-08-17  14:30  Werder Bremen  Fortuna Dusseldorf     1     3   A     0
#
#    HTAG HTR  ...  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  FTR_codes  HTR_codes  \
# 0     2   A  ...     2.04     1.93     1.98     1.91          1          0
# 1     1   D  ...     1.98     2.04     1.91     1.97          2          1
# 2     0   D  ...     1.97     2.06     1.90     1.99          2          1
# 3     2   D  ...     2.15     1.91     2.03     1.85          2          1
# 4     1   A  ...     1.95     2.11     1.89     2.00          0          0
#
#    opp_codes  team_codes  hour  day_code
# 0         10           1    19         4
# 1          0           4    14         5
# 2         14           8    14         5
# 3         15          12    14         5
# 4          7          20    14         5
#
# [5 rows x 110 columns]

# %%
matches["target"] = (matches["FTR_code"] == 2)

# %%
from sklearn.model_selection import train_test_split
